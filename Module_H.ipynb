# %% [markdown]
# <a href="https://colab.research.google.com/github/RichardLowther/MAT-421/blob/main/Module_H.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Richard Lowther
#
# MAT 421 HW 10
#
# Chapter 22
#
# 22.1 ODE Initial Value Problem Statement

# %%
# An ordinary differential equation or ODE is a differential equation where the independent variable, and therefore also the derivatives, is in one dimension
# A general solution to a differential equation is a g(x) that satisfies the differential equation.
# For an ODE of order n, a particular solution is a p(x)that satisfies the differential equation and n explicitly known values of the solution, or its derivatives, at certain points.
# In some cases, the initial value of an ODE from its 0th order to (n-1)th order is known and can be used to find the nth order's value.

# %% [markdown]
# 22.2 Reduction of Order

# %%
# Method to solve initial value problems that are not in the first order
# Consider a vector, S(t), which is the state of the system as a function of time.
# The state of a system is a collection of all the dependent variables that are relevant to the behavior of the system.
# It can then be derivatized to turn an nth order ODE into n first order ODEs that are coupled together, meaning they share the same terms.

# %% [markdown]
# 22.3 The Euler Method

# %%
# F is a function that returns the derivative, or change, of a state given a time and state value.
# Let t be a numerical grid of the interval [t0,tf] with spacing h. Without loss of generality, we assume that t0 = 0, and that tf = Nh for some positive integer, N.
# S(t_j+1) = S(t_j) + hF(t_j,S(t_j)) is the Explicit Euler Formula

# Differential equation df(t)/dt = e^−t with initial condition f0 = −1 and has the exact solution f(t) = −e^−t
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# Define parameters
f = lambda t, s: np.exp(-t) # ODE
h = 0.1 # Step size
t = np.arange(0, 1 + h, h) # Numerical grid
s0 = -1 # Initial Condition

# Explicit Euler Method
s = np.zeros(len(t))
s[0] = s0

for i in range(0, len(t) - 1):
    s[i + 1] = s[i] + h*f(t[i], s[i])

plt.figure(figsize = (12, 8))
plt.plot(t, s, 'bo--', label='Approximate')
plt.plot(t, -np.exp(-t), 'g', label='Exact')
plt.title('Approximate and Exact Solution \
for Simple ODE with Step Size h = 0.1')
plt.xlabel('t')
plt.ylabel('f(t)')
plt.grid()
plt.legend(loc='lower right')
plt.show()

# %%
# With a smaller step size, we can plot a curve that is much closer to the exact

h = 0.01 # Step size
t = np.arange(0, 1 + h, h) # Numerical grid
s0 = -1 # Initial Condition

# Explicit Euler Method
s = np.zeros(len(t))
s[0] = s0

for i in range(0, len(t) - 1):
    s[i + 1] = s[i] + h*f(t[i], s[i])

plt.figure(figsize = (12, 8))
plt.plot(t, s, 'b--', label='Approximate')
plt.plot(t, -np.exp(-t), 'g', label='Exact')
plt.title('Approximate and Exact Solution \
for Simple ODE with Step Size h = 0.01')
plt.xlabel('t')
plt.ylabel('f(t)')
plt.grid()
plt.legend(loc='lower right')
plt.show()
